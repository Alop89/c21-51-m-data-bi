# %% [markdown]
# ## Carga de librerías

# %%
# Carga de librerías 

import os
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# ## Carga de datos

# %%
# URL 
customers_url = "https://raw.githubusercontent.com/Alop89/c21-51-m-data-bi/main/data/customers.csv"
orders_url = "https://raw.githubusercontent.com/Alop89/c21-51-m-data-bi/refs/heads/main/data/orders.csv"
products_url = "https://raw.githubusercontent.com/Alop89/c21-51-m-data-bi/refs/heads/main/data/products.csv"
sales_url = "https://raw.githubusercontent.com/Alop89/c21-51-m-data-bi/refs/heads/main/data/sales.csv"

# Carga del dataset
customers = pd.read_csv(customers_url)
orders = pd.read_csv(orders_url)
products = pd.read_csv(products_url)
sales = pd.read_csv(sales_url)

# %% [markdown]
# ### Verificación de datos

# %%
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customer_id    1000 non-null   int64
#  1   customer_name  1000 non-null   object
#  2   gender         1000 non-null   object
#  3   age            1000 non-null   int64
#  4   home_address   1000 non-null   object
#  5   zip_code       1000 non-null   int64
#  6   city           1000 non-null   object
#  7   state          1000 non-null   object
#  8   country        1000 non-null   object
# dtypes: int64(3), object(6)
# memory usage: 70.4+ KB

# %%
customers.sample(10)
# Out:
#      customer_id         customer_name       gender  age  \
# 243          244         Faunie Cooney         Male   38
# 17            18         Chan Duchesne         Male   79
# 87            88      Kendall Jakubski         Male   78
# 909          910       Basilio Tomsett     Bigender   67
# 462          463  Iago Jedrzaszkiewicz      Agender   58
# 489          490        Bank Sargeaunt         Male   57
# 345          346       Kerianne Parris  Genderqueer   40
# 921          922            Adena Venn   Polygender   53
# 234          235           Beck Oldham   Non-binary   32
# 304          305          Meryl Kender  Genderqueer   25
#
#                        home_address  zip_code               city  \
# 243      36 Christian PlaceApt. 409      6354   Port Chelseaport
# 17          13 Bailey ManorApt. 848      7171         Walterland
# 87     331 Leah Station StSuite 445      3111          Port Liam
# 909     880 O'neill StreetSuite 066      7783       Scarlettfort
# 462       00 Lockman TrackSuite 564       387  Lake Mikaylashire
# 489         74 King SummitSuite 021      7633          Mollyland
# 345     59 Bergstrom GroveSuite 260      6060          Olsonbury
# 921         048 Kayla RoadSuite 099       839        Jordanburgh
# 234  7836 Kessler CrescentSuite 055      7158            Miafurt
# 304      0052 Benjamin MewsApt. 635      7024         Lake Aidan
#
#                             state    country
# 243                      Victoria  Australia
# 17                New South Wales  Australia
# 87                South Australia  Australia
# 909               New South Wales  Australia
# 462  Australian Capital Territory  Australia
# 489               New South Wales  Australia
# 345            Northern Territory  Australia
# 921                      Victoria  Australia
# 234                      Tasmania  Australia
# 304  Australian Capital Territory  Australia

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_id       1000 non-null   int64
#  1   customer_id    1000 non-null   int64
#  2   payment        1000 non-null   int64
#  3   order_date     1000 non-null   object
#  4   delivery_date  1000 non-null   object
# dtypes: int64(3), object(2)
# memory usage: 39.2+ KB

# %%
# Cambio de formato de columasn 'order_date' y 'delivery_date' a fecha

orders['order_date'] = pd.to_datetime(orders['order_date'])
orders['delivery_date'] = pd.to_datetime(orders['delivery_date'])

# %%
orders.sample(10)
# Out:
#      order_id  customer_id  payment order_date delivery_date
# 418       419          745    19518 2021-10-20    2021-11-10
# 989       990           87    40306 2021-08-17    2021-09-06
# 532       533          558    28560 2021-06-04    2021-06-09
# 2           3          774    46763 2021-10-08    2021-11-03
# 915       916          189    31001 2021-10-12    2021-10-19
# 449       450          648    12078 2021-04-30    2021-05-05
# 977       978          827    24589 2021-04-24    2021-05-18
# 257       258          742    38266 2021-10-21    2021-11-13
# 53         54          195    13681 2021-04-25    2021-05-17
# 253       254          571    57662 2021-08-07    2021-09-03

# %%
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1260 entries, 0 to 1259
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   product_ID    1260 non-null   int64
#  1   product_type  1260 non-null   object
#  2   product_name  1260 non-null   object
#  3   size          1260 non-null   object
#  4   colour        1260 non-null   object
#  5   price         1260 non-null   int64
#  6   quantity      1260 non-null   int64
#  7   description   1260 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 78.9+ KB

# %%
products.sample(10)
# Out:
#       product_ID product_type       product_name size  colour  price  \
# 496          496       Jacket        Windbreaker    S  orange    109
# 1088        1088     Trousers            Cropped    L     red     99
# 467          467       Jacket             Puffer    M  yellow    110
# 1234        1234     Trousers  Tracksuit Bottoms   XL  orange     91
# 1214        1214     Trousers            Pleated   XL    blue     90
# 21            21        Shirt       Oxford Cloth    S    blue    114
# 287          287        Shirt       Cuban Collar    M  orange     93
# 698          698       Jacket              Parka    L  violet    119
# 1019        1019     Trousers        Relaxed Leg   XL     red     95
# 7              7        Shirt       Oxford Cloth    M  orange    114
#
#       quantity                                        description
# 496         55     A orange coloured, S sized, Windbreaker Jacket
# 1088        63          A red coloured, L sized, Cropped Trousers
# 467         44          A yellow coloured, M sized, Puffer Jacket
# 1234        42  A orange coloured, XL sized, Tracksuit Bottoms...
# 1214        55        A blue coloured, XL sized, Pleated Trousers
# 21          51       A blue coloured, S sized, Oxford Cloth Shirt
# 287         49     A orange coloured, M sized, Cuban Collar Shirt
# 698         53           A violet coloured, L sized, Parka Jacket
# 1019        50     A red coloured, XL sized, Relaxed Leg Trousers
# 7           77     A orange coloured, M sized, Oxford Cloth Shirt

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sales_id        5000 non-null   int64
#  1   order_id        5000 non-null   int64
#  2   product_id      5000 non-null   int64
#  3   price_per_unit  5000 non-null   int64
#  4   quantity        5000 non-null   int64
#  5   total_price     5000 non-null   int64
# dtypes: int64(6)
# memory usage: 234.5 KB

# %%
sales.sample(10)
# Out:
#       sales_id  order_id  product_id  price_per_unit  quantity  total_price
# 263        263        60        1054              93         2          186
# 3364      3364       677         838             117         2          234
# 1872      1872       376         110              92         2          184
# 2256      2256       458         459             118         3          354
# 3529      3529       709         184              98         1           98
# 437        437        98        1022              90         2          180
# 4778      4778       958        1184              99         2          198
# 2792      2792       558         222             106         2          212
# 1980      1980       398         503             102         1          102
# 4165      4165       829         592             100         2          200

# %% [markdown]
# ## Análisis exploratorio de datos

# %%
# Distribución de edades de los usuarios 
# Crear los subplots
fig, axs = plt.subplots(1, 2, figsize=(15, 8))

# Subplot 1
customer_age = customers['age']
sns.histplot(customer_age, ax=axs[0], kde=True, color = 'blue') 
axs[0].set_title('Distribución de edades de usuarios')
axs[0].set_ylabel('Conteo')
axs[0].set_xlabel('Edad de usuarios')

# Subplot 2
customer_gender = customers['gender']
sns.histplot(customer_gender, ax=axs[1], kde = True)
axs[1].set_title('Distribución de géneros de los usuarios')
axs[1].set_ylabel('Conteo')
axs[1].set_xlabel('Géneros')
plt.xticks(rotation = 45)

plt.tight_layout()
plt.show()

# %%
# Diagrama de cajas y bigotes sobre la edad de los usuarios
plt.figure(figsize=(10,8))
sns.boxplot(customer_age)
plt.title('Boxplot de edad de usuarios')
plt.ylabel('Edad')
# Out:
# Text(0, 0.5, 'Edad')

# %%
# Distribución de usuarios por ciudad y por estado 

fig, axs = plt.subplots(2, 1, figsize=(15, 15))

# Subplot 1
customres_city = customers['city'].value_counts().sort_values(ascending = False).head(10)
sns.boxplot(customres_city, ax=axs[0]) 
axs[0].set_title('Distribución usuarios para las 10 principales ciudades')
axs[0].set_ylabel('Conteo')
axs[0].set_xlabel('Ciudad')


# Subplot 2
customer_state = customers['state']
sns.histplot(customer_state, ax=axs[1], kde = True)
axs[1].set_title('Distribución usuario por estado')
axs[1].set_ylabel('Conteo')
axs[1].set_xlabel('Estado')
plt.xticks(rotation = 45)

plt.tight_layout()
plt.show()
